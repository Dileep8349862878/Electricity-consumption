# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb
from sklearn.metrics import mean_squared_error
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('PJME_hourly.csv')

# %%
df
# Out:
#                    Datetime  PJME_MW
# 0       2002-12-31 01:00:00  26498.0
# 1       2002-12-31 02:00:00  25147.0
# 2       2002-12-31 03:00:00  24574.0
# 3       2002-12-31 04:00:00  24393.0
# 4       2002-12-31 05:00:00  24860.0
# ...                     ...      ...
# 145361  2018-01-01 20:00:00  44284.0
# 145362  2018-01-01 21:00:00  43751.0
# 145363  2018-01-01 22:00:00  42402.0
# 145364  2018-01-01 23:00:00  40164.0
# 145365  2018-01-02 00:00:00  38608.0
#
# [145366 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145366 entries, 0 to 145365
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Datetime  145366 non-null  object
#  1   PJME_MW   145366 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 2.2+ MB

# %%
df = df.set_index("Datetime")

# %%
df.isnull().sum()
# Out:
# PJME_MW    0
# dtype: int64

# %%
df.describe()
# Out:
#              PJME_MW
# count  145366.000000
# mean    32080.222831
# std      6464.012166
# min     14544.000000
# 25%     27573.000000
# 50%     31421.000000
# 75%     35650.000000
# max     62009.000000

# %%
df.shape
# Out:
# (145366, 1)

# %%
import matplotlib.pyplot as plt
df.plot(style='.',
        figsize=(15, 5),
        color=color_pal[0],
        title='PJME Energy Use in MW')

plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(rotation=10)
plt.xlabel('Date')
plt.ylabel('Energy Use (MW)')
plt.title('PJME Energy Use in MW', fontsize=16)
plt.tight_layout()
plt.show()

# %%
df.index = pd.to_datetime(df.index)
train = df.loc[df.index < '2015-01-01']
test = df.loc[df.index >= '2015-01-01']

# %%
fig ,ax  = plt.subplots(figsize=(20,8))
train.plot(ax=ax,label='Training_set',color='blue')
test.plot(ax=ax,label ="Test_set",color='red')
ax.axvline(x=pd.Timestamp('2015-01-01'), color='black', linestyle='--', lw=2, label='Train/Test Split')

ax.set_title('Training and Test Set Split', fontsize=16)
ax.set_xlabel('Date', fontsize=14)
ax.set_ylabel('Energy Usage (MW)', fontsize=14)
ax.legend()

plt.tight_layout()
plt.show()

# %%
def create_features(df):

    df = df.copy()
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    df['weekofyear'] = df.index.isocalendar().week
    return df

df = create_features(df)

# %%
df
# Out:
#                      PJME_MW  hour  dayofweek  quarter  month  year  \
# Datetime
# 2002-12-31 01:00:00  26498.0     1          1        4     12  2002
# 2002-12-31 02:00:00  25147.0     2          1        4     12  2002
# 2002-12-31 03:00:00  24574.0     3          1        4     12  2002
# 2002-12-31 04:00:00  24393.0     4          1        4     12  2002
# 2002-12-31 05:00:00  24860.0     5          1        4     12  2002
# ...                      ...   ...        ...      ...    ...   ...
# 2018-01-01 20:00:00  44284.0    20          0        1      1  2018
# 2018-01-01 21:00:00  43751.0    21          0        1      1  2018
# 2018-01-01 22:00:00  42402.0    22          0        1      1  2018
# 2018-01-01 23:00:00  40164.0    23          0        1      1  2018
# 2018-01-02 00:00:00  38608.0     0          1        1      1  2018
#
#                      dayofyear  dayofmonth  weekofyear
# Datetime
# 2002-12-31 01:00:00        365          31           1
# ...

# %%
fig, ax = plt.subplots(figsize=(15, 8))
sns.boxplot(data=df, x='hour', y='PJME_MW')
ax.set_title('MW by Hour')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 8))
sns.boxplot(data=df, x='year', y='PJME_MW')
ax.set_title('MW by Hour')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 8))
sns.boxplot(data=df, x='month', y='PJME_MW')
ax.set_title('MW by Hour')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 8))
sns.boxplot(data=df, x='quarter', y='PJME_MW')
ax.set_title('MW by Hour')
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

adf_resul = adfuller(df['PJME_MW'])

# %%
adf_resul
# Out:
# (-18.8289127290842,
#  2.022124508152674e-30,
#  74,
#  145291,
#  {'1%': -3.430395009088914,
#   '5%': -2.861559893380481,
#   '10%': -2.5667805885384065},
#  2296512.8411437003)

# %%
adf_result = (-18.8289127290842, 
              2.022124508152674e-30, 
              74, 
              145291, 
              {'1%': -3.430395009088914, '5%': -2.861559893380481, '10%': -2.5667805885384065}, 
              2296512.8411437003)

# %%
adf_dict = {
    'Test Statistic': adf_result[0],
    'p-value': adf_result[1],
    'Lags Used': adf_result[2],
    'Number of Observations Used': adf_result[3],
    'Critical Values (1%)': adf_result[4]['1%'],
    'Critical Values (5%)': adf_result[4]['5%'],
    'Critical Values (10%)': adf_result[4]['10%'],
    'Maximized Information Criterion': adf_result[5]
}

# %%
adf_df = pd.DataFrame(list(adf_dict.items()), columns=['Metric', 'Value'])
adf_df
# Out:
#                             Metric         Value
# 0                   Test Statistic -1.882891e+01
# 1                          p-value  2.022125e-30
# 2                        Lags Used  7.400000e+01
# 3      Number of Observations Used  1.452910e+05
# 4             Critical Values (1%) -3.430395e+00
# 5             Critical Values (5%) -2.861560e+00
# 6            Critical Values (10%) -2.566781e+00
# 7  Maximized Information Criterion  2.296513e+06

# %%
train = create_features(train)
test = create_features(test)

# %%
FEATURES = ['dayofyear', 'hour', 'dayofweek', 'quarter', 'month', 'year']
TARGET = 'PJME_MW'

X_train = train[FEATURES]
y_train = train[TARGET]

X_test = test[FEATURES]
y_test = test[TARGET]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',
                       n_estimators=1000,
                       early_stopping_rounds=50,
                       objective='reg:linear',
                       max_depth=3,
                       learning_rate=0.01)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:32605.13970	validation_1-rmse:31657.15729
# F:\SOFTWARE\anaconda\Lib\site-packages\xgboost\core.py:158: UserWarning: [21:46:57] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [100]	validation_0-rmse:12584.35462	validation_1-rmse:11747.28803
# [200]	validation_0-rmse:5837.33066	validation_1-rmse:5363.58554
# [300]	validation_0-rmse:3923.28511	validation_1-rmse:4020.48045
# [400]	validation_0-rmse:3447.54638	validation_1-rmse:3860.60088
# [500]	validation_0-rmse:3288.19208	validation_1-rmse:3816.37862
# [600]	validation_0-rmse:3206.55619	validation_1-rmse:3779.04119
# [700]	validation_0-rmse:3153.61368	validation_1-rmse:3754.45684
# [800]	validation_0-rmse:3114.34038	validation_1-rmse:3738.38209
# ...

# %%
fi = pd.DataFrame(data=reg.feature_importances_,
             index=reg.feature_names_in_,
             columns=['importance'])
fi.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.show()

# %%
test['prediction'] = reg.predict(X_test)
df = df.merge(test[['prediction']], how='left', left_index=True, right_index=True)
ax = df[['PJME_MW']].plot(figsize=(15, 5))
df['prediction'].plot(ax=ax, style='.')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Raw Dat and Prediction')
plt.show()

# %%
score = np.sqrt(mean_squared_error(test['PJME_MW'], test['prediction']))
print(f'RMSE Score on Test set: {score:0.2f}')
# Out:
# RMSE Score on Test set: 3726.80

# %%
test['error'] = np.abs(test[TARGET] - test['prediction'])
test['date'] = test.index.date
test.groupby(['date'])['error'].mean().sort_values(ascending=False).head(10)
# Out:
# date
# 2016-08-13    12879.484619
# 2016-08-14    12772.887207
# 2015-02-20    11186.031494
# 2016-09-09    10966.513102
# 2016-09-10    10889.102214
# 2018-01-06    10642.975830
# 2016-08-12    10041.172689
# 2015-02-21     9988.168783
# 2015-02-16     9900.809326
# 2018-01-07     9852.571370
# Name: error, dtype: float64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomp = seasonal_decompose(df['PJME_MW'], period=52, model='additive', extrapolate_trend='freq')

# %%
df['trend'] = decomp.trend
df['seasonal'] = decomp.seasonal

# %%
plt.figure(figsize=(25,12))
plt.plot(df['trend'], color='dodgerblue')

# %%
from pandas.plotting import autocorrelation_plot

# %%
autocorrelation_plot(df['PJME_MW'])
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
f, ax = plt.subplots(nrows=2 ,ncols=1, figsize=(16, 8))

plot_acf(df['PJME_MW'], lags=100, ax=ax[0])
plot_pacf(df['PJME_MW'], lags=100, ax=ax[1])

plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
import pmdarima as pm

model = pm.auto_arima(y_train, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1947531.980, Time=21.91 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=2693442.039, Time=1.34 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=1.78 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=2539164.197, Time=23.98 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=1920758.489, Time=13.21 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=2.48 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=1904996.565, Time=77.21 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=inf, Time=3.48 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=1920436.803, Time=85.93 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=1920201.422, Time=14.34 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=1910587.100, Time=64.48 sec
#
# Best model:  ARIMA(3,0,1)(0,0,0)[0]
# Total fit time: 311.363 seconds
#                                SARIMAX Results
# ...

# %%
train_size = int(0.85 * len(df))
test_size = len(df) - train_size

train, test = df.iloc[:train_size], df.iloc[train_size:]

# Features and Target
FEATURES = ['dayofyear', 'hour', 'dayofweek', 'quarter', 'month', 'year']
TARGET = 'PJME_MW'

X_train = train[FEATURES]
y_train = train[TARGET]
X_test = test[FEATURES]
y_test = test[TARGET]

# ARIMA Model
arima_model = ARIMA(y_train, order=(3, 0, 0))  # Adjust order as necessary

# Fit the ARIMA model
model_fit = arima_model.fit()

# ARIMA predictions (forecast for test size)
y_pred_arima = model_fit.forecast(steps=test_size)

# Add ARIMA predictions to the test set
test['arima_prediction'] = y_pred_arima.values

# Assuming you have a regression model (e.g., XGBoost or RandomForest) already fitted as `reg`
# Make regression predictions
test['regression_prediction'] = reg.predict(X_test)

# Merge predictions back into the original df for plotting
df = df.merge(test[['arima_prediction', 'regression_prediction']], how='left', left_index=True, right_index=True)

# Plot actual values and predictions
ax = df[['PJME_MW']].plot(figsize=(15, 5), label='Truth Data')
df['arima_prediction'].plot(ax=ax, style='--', color='red', label='ARIMA Predictions')
df['regression_prediction'].plot(ax=ax, style='.', color='blue', label='Regression Predictions')

# Plot settings
plt.legend(['Truth Data', 'ARIMA Predictions', 'Regression Predictions'])
ax.set_title('Actual Data and Predictions')
plt.show()
# Out:
# F:\SOFTWARE\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# F:\SOFTWARE\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# F:\SOFTWARE\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# F:\SOFTWARE\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %%
score = np.sqrt(mean_squared_error(test['PJME_MW'], test['prediction']))
print(f'RMSE Score on Test set: {score:0.2f}')
# Out:
# RMSE Score on Test set: 3797.53
